# %% [markdown]
# Нарисуйте график функции:   для некоторых (2-3 различных) значений параметров k, a, b
# 𝑦= k*cos(x-a) + b

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-20, 20, 100)
y1 = 2*np.cos(x - 1) + 3
y2 = np.cos(x + 5) + 2
y3 = 4*np.cos(x - 7) + 10
plt.plot(x, y1, label="y1")
plt.plot(x, y2, label="y2")
plt.plot(x, y3, label="y3")
plt.xlabel("x")
plt.ylabel("y")
plt.axis([-10, 10, 0, 20])
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# 3.1 Задание (в программе)
# Напишите код, который будет переводить полярные координаты в декартовы.

# %%
R = 2
a = np.pi / 2
x = R * np.cos(a)
y = R * np.sin(a)
x, y
# Out:
# (1.2246467991473532e-16, 2.0)

# %% [markdown]
# 3.2 Напишите код, который будет рисовать график окружности в полярных координатах.

# %%
R = 5
y = R
plt.polar(y)

# %% [markdown]
# 3.3 Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %%
x = np.linspace(0, 5, 100)
y = 2*x + 3
plt.polar(x, y)

# %% [markdown]
# 4.1 Решите систему уравнений exp(x) + x∙(1 – y) = 1
# y = x**2 – 1

# %%
x = np.linspace(-20, 20, 100)
y1 = x**2 - 1
y2 = (np.exp(x) + x - 1) / x
plt.plot(x, y1, label = "y1")
plt.plot(x, y2, label = "y2")
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(-2,30)
plt.xlim(-5,7)
plt.grid(True)
plt.legend(loc="upper right")
plt.show()

# %%
from scipy.optimize import fsolve 
def equations(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x* (1 - y) - 1)
x1, y1 = fsolve(equations, (-2, 5))
print(x1, y1)
# Out:
# -1.5818353528958997 1.5022030836712943

# %%
x2, y2 = fsolve(equations, (5, 25))
print(x2, y2)
# Out:
# 4.200105841487946 16.640889079631396

# %%
x3, y3 = fsolve(equations, (3, 9))
print(x3, y3)
# Out:
# 2.6181455730835452 5.8546862418539565

# %% [markdown]
# 4.2 Решите систему уравнения и неравенства exp(x) + x∙(1 – y) - 1 > 0
# y = x**2 – 1

# %%
# решим уравнение y = x**2 – 1
def f(x):
    return (x**2 - 1)
x1 = fsolve(f, -2)
print(x1)
# Out:
# [-1.]

# %%
x2 = fsolve(f, 2)
print(x2)
# Out:
# [1.]

# %%
#подставим корни в неравенство
np.exp(1) + 1*(1 - 0) - 1
# Out:
# 2.718281828459045

# %%
np.exp(-1) + (-1)*(1 - 0) - 1
# Out:
# -1.6321205588285577

# %%
#следовательно решением системы уравнения и неравенства будет одна точка (1, 0)
